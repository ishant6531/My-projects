# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (158, 12)

# %%
df.isnull().sum()
#finding sum of null values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
#Making Heatmap of null values
#since their are no null value we are getting this color which denote 0% null values

# %%
df.info
# Out:
# <bound method DataFrame.info of          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
#Finding correlation 
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
sns.heatmap(df.corr())

# %% [markdown]
# # Bivriate Analysis

# %%
sns.lineplot(x="Happiness Score",y="Economy (GDP per Capita)",data=df)
#Result - Economy Gdp has positive linear relation with happiness score

# %%
sns.lineplot(x="Happiness Score",y="Freedom",data=df)
#Freedom has positive linear relation with happines score

# %%
sns.scatterplot(x="Happiness Score", y="Trust (Government Corruption)",data=df)

# %%
sns.scatterplot(x="Happiness Score", y="Health (Life Expectancy)",data=df)

# %% [markdown]
# # Multivariate analysis

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C5D101AE88>,
# ...
#       dtype=object)

# %%
sns.pairplot(df)
#plotting pairplot

# %%
df.plot(kind='box',subplots=True,layout=(3,7),figsize=(20,20))
#their are some outliners and we have to remove them
# Out:
# Happiness Rank                      AxesSubplot(0.125,0.657941;0.0945122x0.222059)
# Happiness Score                  AxesSubplot(0.238415,0.657941;0.0945122x0.222059)
# Standard Error                   AxesSubplot(0.351829,0.657941;0.0945122x0.222059)
# Economy (GDP per Capita)         AxesSubplot(0.465244,0.657941;0.0945122x0.222059)
# Family                           AxesSubplot(0.578659,0.657941;0.0945122x0.222059)
# Health (Life Expectancy)         AxesSubplot(0.692073,0.657941;0.0945122x0.222059)
# Freedom                          AxesSubplot(0.805488,0.657941;0.0945122x0.222059)
# Trust (Government Corruption)       AxesSubplot(0.125,0.391471;0.0945122x0.222059)
# Generosity                       AxesSubplot(0.238415,0.391471;0.0945122x0.222059)
# Dystopia Residual                AxesSubplot(0.351829,0.391471;0.0945122x0.222059)
# dtype: object

# %% [markdown]
# # Univarate analysis

# %%
plt.hist(df["Happiness Score"],bins=10)
plt.title("Happiness Score")

plt.show()

# %%
plt.boxplot(df["Family"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c5d8680288>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c5d8684908>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c5d8680f08>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c5d86880c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c5d8668f88>],
#  'means': []}

# %%
plt.violinplot(df["Freedom"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1c5d8671988>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1c5d5aecbc8>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1c5d8eafa48>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1c5d8eaff08>}

# %%
plt.violinplot(df["Generosity"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1c5d8716948>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1c5d8716588>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1c5d871cb08>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1c5d871cfc8>}

# %%
plt.violinplot(df["Dystopia Residual"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1c5d878b2c8>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1c5d8783fc8>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1c5d878bbc8>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1c5d878fb08>}

# %% [markdown]
# # Removing Outliners and Skewness

# %%
df1=df.drop(["Country","Region","Happiness Rank"],axis=1)
df1
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
#calculating Z score
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
# array([[1.93736005, 0.80592569, 1.36962124, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.91458063, 0.05588945, 1.13522625, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.88479215, 0.8544869 , 1.19286069, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [2.0761992 , 0.13253425, 0.45524543, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [2.1646885 , 2.26396166, 2.06756644, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [2.22251319, 1.13418227, 1.58633379, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
#Removing Outliners 
from scipy import stats
df3=df1[(z<3).all(axis=1)]

# %%
df3
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 150            3.655         0.05141                   0.46534  0.77115
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 156            2.905         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
#checking Skewness
df3.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#Removing Skewness
import numpy as np
for col in df3.columns:
    if df3.skew().loc[col]>0.55:
         df3[col]=np.log1p(df3[col])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
print(scaler.fit(df3))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
df3.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   1.193808
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.095190
# Generosity                       0.433539
# Dystopia Residual               -0.021144
# dtype: float64

# %%
import numpy as np
for col in df3.columns:
    if df3.skew().loc[col]>0.55:
         df3[col]=np.log1p(df3[col])

# %%
df3.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   1.147288
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    0.945756
# Generosity                       0.433539
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# # Splitting Data into target and Input

# %%
x=df3.iloc[:,1:9]
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0          0.032991                   1.39651  1.34951
# 1          0.046583                   1.30232  1.40223
# 2          0.032214                   1.32548  1.36058
# 3          0.037360                   1.45900  1.33095
# 4          0.034318                   1.32629  1.32261
# ..              ...                       ...      ...
# 150        0.048916                   0.46534  0.77115
# 151        0.041460                   0.25812  0.85188
# 152        0.029922                   0.31982  0.30285
# 154        0.035278                   0.28665  0.35386
# 156        0.079767                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                       0.300476
# 1                     0.94784  0.62877                       0.124250
# 2                     0.87464  0.64938                       0.332501
# ...

# %%
y=df3.iloc[:,0]
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %% [markdown]
# # Importing Necessary libraries

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        regr.fit(x,y)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to",i,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_i=i
    print("max r2 score corresponding to",final_i,"is",max_r_score)
    return final_i

# %%
#Finding best random state value for Linear Regression
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# r2 score corresponding to 42 is 0.9999128837381024
# r2 score corresponding to 43 is 0.9998697266238199
# r2 score corresponding to 44 is 0.9998992797913423
# r2 score corresponding to 45 is 0.9999096423777051
# r2 score corresponding to 46 is 0.9998760463117373
# r2 score corresponding to 47 is 0.9999176186111165
# r2 score corresponding to 48 is 0.9998337035765714
# r2 score corresponding to 49 is 0.9998744115205342
# r2 score corresponding to 50 is 0.9998474314517811
# r2 score corresponding to 51 is 0.9999104915324453
# r2 score corresponding to 52 is 0.9998389461722217
# r2 score corresponding to 53 is 0.9997791126583652
# r2 score corresponding to 54 is 0.9998694924179167
# r2 score corresponding to 55 is 0.9998299420831499
# r2 score corresponding to 56 is 0.9998957526997149
# r2 score corresponding to 57 is 0.9998475452399607
# r2 score corresponding to 58 is 0.9999078627855386
# r2 score corresponding to 59 is 0.9998244829299808
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
print()
# Out:
# Mean r2 score for Linear Regression: 0.996178144660411
# standard deviation in r2 score for Linear Regression 0.0016409744251286388

# %% [markdown]
# # Using GridSearchCv to find best parameters of different algorithims

# %%
sv=SVR()
parameters={'kernel':('linear','rbf'),'C':[1,10]}
gd=GridSearchCV(sv,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")


knn=KNeighborsRegressor()
parameters={'n_neighbors':(1,10)}
gd=GridSearchCV(knn,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

dtc=DecisionTreeRegressor()
parameters={'criterion':('mse', 'friedman_mse', 'mae')}
gd=GridSearchCV(dtc,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")


lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
gd=GridSearchCV(lsreg,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

from sklearn.linear_model import ElasticNet
enr=ElasticNet()
parametors={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(enr,parametors,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}
#
#
# {'n_neighbors': 1}
#
#
# {'criterion': 'friedman_mse'}
#
#
# {'alpha': 0.001}
# {'alpha': 0.001}

# %%
##Finding best random state value for KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=1)
i=maxr2_score(knn,x,y)
# Out:
# r2 score corresponding to 42 is 1.0
# r2 score corresponding to 43 is 1.0
# r2 score corresponding to 44 is 1.0
# r2 score corresponding to 45 is 1.0
# r2 score corresponding to 46 is 1.0
# r2 score corresponding to 47 is 1.0
# r2 score corresponding to 48 is 1.0
# r2 score corresponding to 49 is 1.0
# r2 score corresponding to 50 is 1.0
# r2 score corresponding to 51 is 1.0
# r2 score corresponding to 52 is 1.0
# r2 score corresponding to 53 is 1.0
# r2 score corresponding to 54 is 1.0
# r2 score corresponding to 55 is 1.0
# r2 score corresponding to 56 is 1.0
# r2 score corresponding to 57 is 1.0
# r2 score corresponding to 58 is 1.0
# r2 score corresponding to 59 is 1.0
# r2 score corresponding to 60 is 1.0
# r2 score corresponding to 61 is 1.0
# r2 score corresponding to 62 is 1.0
# r2 score corresponding to 63 is 1.0
# r2 score corresponding to 64 is 1.0
# r2 score corresponding to 65 is 1.0
# r2 score corresponding to 66 is 1.0
# r2 score corresponding to 67 is 1.0
# ...

# %%
print("Mean r2 score for KNeighborsRegressor :",cross_val_score(knn,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNeighborsRegressor",cross_val_score(knn,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for KNeighborsRegressor : -4.20486651417628
# standard deviation in r2 score for KNeighborsRegressor 1.676317312612256

# %%
##Finding best random state value for lasso regressor
lsreg=Lasso(alpha=0.001)
i=maxr2_score(lsreg,x,y)
# Out:
# r2 score corresponding to 42 is 0.9998198708176917
# r2 score corresponding to 43 is 0.9997407021637446
# r2 score corresponding to 44 is 0.9996487927956077
# r2 score corresponding to 45 is 0.999641509583168
# r2 score corresponding to 46 is 0.999665119596077
# r2 score corresponding to 47 is 0.9998216740030982
# r2 score corresponding to 48 is 0.999439245447773
# r2 score corresponding to 49 is 0.9995984937894602
# r2 score corresponding to 50 is 0.9997413529310395
# r2 score corresponding to 51 is 0.9998595486309444
# r2 score corresponding to 52 is 0.9996181914374938
# r2 score corresponding to 53 is 0.9994326397212862
# r2 score corresponding to 54 is 0.9995933884280047
# r2 score corresponding to 55 is 0.9994943549185615
# r2 score corresponding to 56 is 0.9996832087031208
# r2 score corresponding to 57 is 0.9995167518213235
# r2 score corresponding to 58 is 0.9998532286351979
# r2 score corresponding to 59 is 0.9996099592793278
# ...

# %%
print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Lasso Regression: 0.9833447859320563
# standard deviation in r2 score for Lasso Regression 0.0016409744251286388

# %%
dtc=DecisionTreeRegressor(criterion = 'friedman_mse')
i=maxr2_score(dtc,x,y)
# Out:
# r2 score corresponding to 42 is 1.0
# r2 score corresponding to 43 is 1.0
# r2 score corresponding to 44 is 1.0
# r2 score corresponding to 45 is 1.0
# r2 score corresponding to 46 is 1.0
# r2 score corresponding to 47 is 1.0
# r2 score corresponding to 48 is 1.0
# r2 score corresponding to 49 is 1.0
# r2 score corresponding to 50 is 1.0
# r2 score corresponding to 51 is 1.0
# r2 score corresponding to 52 is 1.0
# r2 score corresponding to 53 is 1.0
# r2 score corresponding to 54 is 1.0
# r2 score corresponding to 55 is 1.0
# r2 score corresponding to 56 is 1.0
# r2 score corresponding to 57 is 1.0
# r2 score corresponding to 58 is 1.0
# r2 score corresponding to 59 is 1.0
# r2 score corresponding to 60 is 1.0
# r2 score corresponding to 61 is 1.0
# r2 score corresponding to 62 is 1.0
# r2 score corresponding to 63 is 1.0
# r2 score corresponding to 64 is 1.0
# r2 score corresponding to 65 is 1.0
# r2 score corresponding to 66 is 1.0
# r2 score corresponding to 67 is 1.0
# ...

# %%
print("Mean r2 score for DecisionTreeRegressor:",cross_val_score(dtc,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for DecisionTreeRegressor",cross_val_score(dtc,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for DecisionTreeRegressor: -7.674800829064834
# standard deviation in r2 score for DecisionTreeRegressor 1.7523951221385028

# %%
#Finding best random state value for SVR()
sv=SVR(C=10 ,kernel='linear')
i=maxr2_score(sv,x,y)
# Out:
# r2 score corresponding to 42 is 0.9950089529045367
# r2 score corresponding to 43 is 0.9959967576107202
# r2 score corresponding to 44 is 0.9958912260208774
# r2 score corresponding to 45 is 0.9959607189555382
# r2 score corresponding to 46 is 0.995417664025898
# r2 score corresponding to 47 is 0.9970784413084316
# r2 score corresponding to 48 is 0.9951157349028197
# r2 score corresponding to 49 is 0.9949897275461178
# r2 score corresponding to 50 is 0.9948664787677983
# r2 score corresponding to 51 is 0.9961300287503053
# r2 score corresponding to 52 is 0.9940979602395709
# r2 score corresponding to 53 is 0.9941837067987606
# r2 score corresponding to 54 is 0.9947787711379344
# r2 score corresponding to 55 is 0.99516401289608
# r2 score corresponding to 56 is 0.9958951499596593
# r2 score corresponding to 57 is 0.9948640952015926
# r2 score corresponding to 58 is 0.9947013173715723
# r2 score corresponding to 59 is 0.9944157513636732
# ...

# %%
print("Mean r2 score for SVR():",cross_val_score(sv,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for SVR() ",cross_val_score(sv,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for SVR(): 0.875055064730381
# standard deviation in r2 score for SVR()  0.07612575232539148

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet()
parametors={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(enr,parametors,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
enr=ElasticNet(alpha=0.001)
i=maxr2_score(enr,x,y)
# Out:
# r2 score corresponding to 42 is 0.9997918057254858
# r2 score corresponding to 43 is 0.9997096144692772
# r2 score corresponding to 44 is 0.9996015430156903
# r2 score corresponding to 45 is 0.9995852563665693
# r2 score corresponding to 46 is 0.9996272839785472
# r2 score corresponding to 47 is 0.9998017636435448
# r2 score corresponding to 48 is 0.9993635363651682
# r2 score corresponding to 49 is 0.9995454613529904
# r2 score corresponding to 50 is 0.9997026224864851
# r2 score corresponding to 51 is 0.9998455512377611
# r2 score corresponding to 52 is 0.9995724348395996
# r2 score corresponding to 53 is 0.9993590187418091
# r2 score corresponding to 54 is 0.9995373470020428
# r2 score corresponding to 55 is 0.9994312702152137
# r2 score corresponding to 56 is 0.9996365086498712
# r2 score corresponding to 57 is 0.9994513310889517
# r2 score corresponding to 58 is 0.9998261089742849
# r2 score corresponding to 59 is 0.9995577486011427
# ...

# %%
print("Mean r2 score for Elastic net Regression:",cross_val_score(enr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Elastic net Regression",cross_val_score(enr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Elastic net Regression: 0.9823516126101353
# standard deviation in r2 score for Elastic net Regression 0.024008258372456414

# %% [markdown]
# # we selected Linear Regression  as our final model.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)
lreg=LinearRegression()
lreg.fit(x,y)
y_pred=lreg.predict(x_test)

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is:",r2_score(y_test,y_pred))
# Out:
# RMSE is:  0.009969559239408458
# r2_score is: 0.9999128837381024

# %%
from sklearn.externals import joblib
joblib.dump(lreg,"happiness.pkl")
# Out:
# ['happiness.pkl']
